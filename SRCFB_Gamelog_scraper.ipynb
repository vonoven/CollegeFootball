# %%
# import packages
import urllib3
import csv
from bs4 import BeautifulSoup
import re
import pandas as pd
import datetime

#settings
http = urllib3.PoolManager()
today = datetime.datetime.today()
gamelog_offense = []
year_list = ['2014', '2015', '2016', '2017', '2018']

for school in httpschool_list:
    for year in year_list:
        #scrape the data and write the .csv files
        url = "http://www.sports-reference.com/cfb/schools/"+school+"/"+year+"/gamelog/"
        response = http.request('GET', url)
        soup = BeautifulSoup(response.data)
        cnt = 0
        #print(soup)

        for row in soup.findAll('tr'):
            try:
                col1=row.findAll('th')
                Game=col1[0].string
                col=row.findAll('td')
                Date = col[0].get_text()
                Location = col[1].get_text()
                Opp = col[2].get_text()
                Result = col[3].get_text()
                Pass_cmp = col[4].get_text()
                Pass_att = col[5].get_text()
                Pass_pct = col[6].get_text()
                Pass_yds = col[7].get_text()
                Pass_TD = col[8].get_text()
                Rush_att = col[9].get_text()
                Rush_yds = col[10].get_text()
                Rush_avg = col[11].get_text()
                Rush_TD = col[12].get_text()
                TO_plays = col[13].get_text()
                TO_yds = col[14].get_text()
                TO_avg = col[15].get_text()
                FD_pass = col[16].get_text()
                FD_rush = col[17].get_text()
                FD_pen = col[18].get_text()
                FD_tot = col[19].get_text()
                Pen_num = col[20].get_text()
                Pen_yds = col[21].get_text()
                Turn_fum = col[22].get_text()
                Turn_int = col[23].get_text()
                Turn_tot = col[24].get_text()
                gamelog_offense.append([Game, Date, school, Location, Opp, Result, Pass_cmp, Pass_att, Pass_pct, Pass_yds, Pass_TD,
                               Rush_att, Rush_yds, Rush_avg, Rush_TD, TO_plays, TO_yds, TO_avg, FD_pass,
                               FD_rush, FD_pen, FD_tot, Pen_num, Pen_yds, Turn_fum, Turn_int, Turn_tot])
                cnt += 1
            except:
                pass
        print("Finished writing " + year + school +"  with " + str(cnt) + " records")
# Out:
# /anaconda3/envs/TensorFlow/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Finished writing 2014florida-state  with 15 records
# /anaconda3/envs/TensorFlow/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Finished writing 2015florida-state  with 14 records
# ...

# %%
pitt, ucf, smu, texas-a&m, chicago,

# %%
df=pd.DataFrame(gamelog_offense,columns=['Game', 'Date', 'Team', 'Location', 'Opp', 'Result', 'Pass_cmp',
                                         'Pass_att', 'Pass_pct', 'Pass_yds', 'Pass_TD', 'Rush_att', 'Rush_yds',
                                         'Rush_avg', 'Rush_TD', 'TO_plays', 'TO_yds', 'TO_avg', 'FD_pass', 
                                         'FD_rush', 'FD_pen', 'FD_tot', 'Pen_num', 'Pen_yds', 'Turn_fum',
                                         'Turn_int', 'Turn_tot'])
df
# Out:
#        Game        Date           Team Location                   Opp  \
# 0         1  2014-08-30  florida-state        N        Oklahoma State
# 1         2  2014-09-06  florida-state                        Citadel
# 2         3  2014-09-20  florida-state                        Clemson
# 3         4  2014-09-27  florida-state        @  North Carolina State
# 4         5  2014-10-04  florida-state                    Wake Forest
# 5         6  2014-10-11  florida-state        @              Syracuse
# 6         7  2014-10-18  florida-state                     Notre Dame
# 7         8  2014-10-30  florida-state        @            Louisville
# 8         9  2014-11-08  florida-state                       Virginia
# 9        10  2014-11-15  florida-state        @            Miami (FL)
# 10       11  2014-11-22  florida-state                 Boston College
# 11       12  2014-11-29  florida-state                        Florida
# ...

# %%
df[df['Team'] == 'utah-state']
# Out:
#        Game        Date        Team Location                Opp     Result  \
# 5808      1  2014-08-31  utah-state        @          Tennessee   L (7-38)
# 5809      2  2014-09-06  utah-state                 Idaho State  W (40-20)
# 5810      3  2014-09-13  utah-state                 Wake Forest  W (36-24)
# 5811      4  2014-09-20  utah-state        @     Arkansas State  L (14-21)
# 5812      5  2014-10-03  utah-state        @      Brigham Young  W (35-20)
# 5813      6  2014-10-11  utah-state                   Air Force  W (34-16)
# 5814      7  2014-10-18  utah-state        @     Colorado State  L (13-16)
# 5815      8  2014-10-25  utah-state            Nevada-Las Vegas  W (34-20)
# 5816      9  2014-11-01  utah-state        @             Hawaii  W (35-14)
# 5817     10  2014-11-07  utah-state        @            Wyoming   W (20-3)
# 5818     11  2014-11-15  utah-state                  New Mexico  W (28-21)
# ...

# %%
len(httpschool_list)
# Out:
# 417

# %%
len(gamelog_offense[0])
# Out:
# 27

# %%
naughty = []
for school in httpschool_list:
    if school in nice:
        pass
    else:
        naughty.append(school)

# %%
naughty
# Out:
# ['pitt',
#  'ucf',
#  'smu',
#  'texas-a&m',
#  'chicago',
#  'uab',
#  'utsa',
#  'utep',
#  'ucf',
#  'smu',
#  'florida-a&m',
#  'ucf',
#  'louisiana',
#  'uab',
#  'pitt',
#  'wichita-state',
#  'william-&-mary',
#  'dayton',
#  'tampa',
#  'texas-arlington',
#  'xavier',
#  'west-texas-a&m',
#  'pacific',
#  'utep',
#  'quantico-marines',
#  'detroit-mercy',
#  'boston-university',
#  'hardin-simmons',
#  'marquette',
#  'drake',
#  'yale',
#  'princeton',
#  'pennsylvania',
#  'harvard',
#  'cornell',
#  'dartmouth',
#  'brown',
#  'columbia',
#  'santa-clara',
#  'new-york-university',
#  'san-francisco',
#  'loyola-marymount',
#  'georgetown',
#  "saint-mary's-ca",
#  'merchant-marine',
#  'portland',
#  'bucknell',
#  'great-lakes-navy',
#  'colorado-college',
#  'coast-guard',
#  'iowa-pre-flight',
#  'norman-naval-air-station',
#  'randolph-field',
#  'second-air-force',
#  'march-field',
#  'amarillo-field',
#  "saint-mary's-ca-pre-flight",
#  'alameda-coast-guard',
# ...

# %%
nice = df['Team'].unique()

# %%
df

# %%
df.to_csv('./SRinput/gamelog_offense.csv')

# %%
# import packages
import urllib3
import csv
from bs4 import BeautifulSoup
import re
import pandas as pd
import datetime

#settings
http = urllib3.PoolManager()
today = datetime.datetime.today()
gamelog_offense = []
school = 'florida'
year = '2018'


#scrape the data and write the .csv files
url = "http://www.sports-reference.com/cfb/schools/"+school+"/"+year+"/gamelog/"
response = http.request('GET', url)
soup = BeautifulSoup(response.data)
cnt = 0
#print(soup)

for row in soup.findAll('tr'):
    #print(table)
    #row=table.findAll('tr')
    #print(row)
    try:
        col1=row.findAll('th')
        Game=col1[0].string
        col=row.findAll('td')
        Date = col[1].get_text()
        Opp = col[2].get_text()
        Result = col[3].get_text()
        Pass_cmp = col[4].get_text()
        Pass_att = col[5].get_text()
        Pass_pct = col[6].get_text()
        Pass_yds = col[7].get_text()
        Pass_TD = col[8].get_text()
        Rush_att = col[9].get_text()
        Rush_yds = col[10].get_text()
        Rush_avg = col[11].get_text()
        Rush_TD = col[12].get_text()
  
        gamelog_offense.append([Game, Date, Opp, Result, Pass_cmp, Pass_att, Pass_pct, Pass_yds, Pass_TD,
                       Rush_att, Rush_yds, Rush_avg, Rush_TD, TO_plays, TO_yds, TO_avg, FD_pass,
                       FD_rush, FD_pen, FD_tot, Pen_num, Pen_yds, Turn_fum, Turn_int, Turn_tot])
        cnt += 1
    except:
        pass
print("Finished writing " + school + "  with " + str(cnt) + " records")
# Out:
# /anaconda3/envs/TensorFlow/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Finished writing florida  with 12 records

# %%
#scrape the data and write the .csv files
url = "http://www.sports-reference.com/cfb/schools/"+school+"/"+year+"/gamelog/"
response = http.request('GET', url)
soup = BeautifulSoup(response.data)
cnt = 0
print(soup.prettify())
# Out:
# /anaconda3/envs/TensorFlow/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/cfb/www" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
#    <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201811161" rel="dns-prefetch"/>
#    <!-- no:cookie fast load the css.           -->
#    <link crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net" rel="preconnect"/>
#    <link crossorigin="" href="https://d17lgqwvsissft.cloudfront.net" rel="preconnect"/>
#    <style>
# ...

# %%
conference_mstr = pd.read_csv('./input/conference_master.csv')
school_list_raw = conference_mstr['School']
school_list_lower = school_list_raw.apply(lambda x: x.lower())
school_list_dash = school_list_lower.apply(lambda x: x.replace(' ', '-'))
school_list_left = school_list_dash.apply(lambda x: x.replace('(', ''))
httpschool_list = school_list_left.apply(lambda x: x.replace(')', ''))
conference_mstr['HTTP_school'] = httpschool_list
conference_mstr
# Out:
#      Unnamed: 0      Conf                  School  From    To  Yrs  Games  \
# 0             0       acc           Florida State  1992  2018   27    336
# 1             1       acc           Virginia Tech  2004  2018   15    197
# 2             2       acc              Miami (FL)  2004  2018   15    188
# 3             3       acc                 Clemson  1953  2018   66    761
# 4             4       acc              Louisville  2014  2018    5     63
# 5             5       acc            Georgia Tech  1983  2018   36    429
# 6             6       acc                    Pitt  2013  2018    6     75
# 7             7       acc          Boston College  2005  2018   14    178
# 8             8       acc          North Carolina  1953  2018   66    738
# 9             9       acc    North Carolina State  1953  2018   66    737
# 10           10       acc                Syracuse  2013  2018    6     72
# 11           11       acc                    Duke  1953  2018   66    730
# ...
