# %% [markdown]
# ### Creates the master history of gamelogs between 2014 and 2017, saves to disk

# %% [markdown]
# ### Work on the Offense GL

# %%
# import packages
import urllib3
import certifi
import csv
from bs4 import BeautifulSoup
import re
import pandas as pd
import datetime

#settings
http = urllib3.PoolManager(
        cert_reqs='CERT_REQUIRED',
        ca_certs=certifi.where())
today = datetime.datetime.today()
gamelog_offense = []
noGLteams = []
translator = pd.read_csv('./SRinput/valid_school_translation.csv')
HTTPnames = translator['HTTPname']

for school in HTTPnames:
    for year in range(2014, 2018):
        #scrape the data and write the .csv files
        url = "http://www.sports-reference.com/cfb/schools/"+school+"/"+str(year)+"/gamelog/"
        response = http.request('GET', url)
        soup = BeautifulSoup(response.data, features="html.parser")
        cnt = 0
        #print(soup)

        for row in soup.findAll('tr'):
            #print(table)
            #row=table.findAll('tr')
            #print(row)
            try:
                col1=row.findAll('th')
                Game=col1[0].string
                col=row.findAll('td')
                Date = col[0].get_text()
                Loc = col[1].get_text()
                Team = translator[translator['HTTPname'] == school]['School'].values[0]
                Opp = col[2].get_text()
                Result = col[3].get_text()
                Pass_cmp = col[4].get_text()
                Pass_att = col[5].get_text()
                Pass_pct = col[6].get_text()
                Pass_yds = col[7].get_text()
                Pass_TD = col[8].get_text()
                Rush_att = col[9].get_text()
                Rush_yds = col[10].get_text()
                Rush_avg = col[11].get_text()
                Rush_TD = col[12].get_text()
                TO_plays = col[13].get_text()
                TO_yds = col[14].get_text()
                TO_avg = col[15].get_text()
                FD_pass = col[16].get_text()
                FD_rush = col[17].get_text()
                FD_pen = col[18].get_text()
                FD_tot = col[19].get_text()
                Pen_num = col[20].get_text()
                Pen_yds = col[21].get_text()
                Turn_fum = col[22].get_text()
                Turn_int = col[23].get_text()
                Turn_tot = col[24].get_text()
                Season = year

                gamelog_offense.append([Season, Game, Date, Team, Loc, Opp, Result, Pass_cmp, Pass_att, Pass_pct, Pass_yds, Pass_TD,
                               Rush_att, Rush_yds, Rush_avg, Rush_TD, TO_plays, TO_yds, TO_avg, FD_pass,
                               FD_rush, FD_pen, FD_tot, Pen_num, Pen_yds, Turn_fum, Turn_int, Turn_tot])
                cnt += 1
            except:
                pass
        if cnt > 0:
            print("Finished writing " + str(year), school + " with " + str(cnt) + " records")
        else:
            noGLteams.append(school)
        
GL_offense_final=pd.DataFrame(gamelog_offense,columns=['Season', 'Game', 'Date', 'Team', 'Loc', 'Opp', 'Result', 'Pass_cmp',
                                              'Pass_att', 'Pass_pct', 'Pass_yds', 'Pass_TD',
                                              'Rush_att', 'Rush_yds', 'Rush_avg', 'Rush_TD', 'TO_plays',
                                              'TO_yds', 'TO_avg', 'FD_pass',
                                              'FD_rush', 'FD_pen', 'FD_tot', 'Pen_num', 'Pen_yds', 'Turn_fum',
                                              'Turn_int', 'Turn_tot'])
GL_offense_final.to_csv('./SRinput/GL_offense_2014_to_2017.csv')

# %%
GL_offense_final.head()

# %%
noGLteams

# %% [markdown]
# ### Work on the Defense GL

# %%
# import packages
import urllib3
import certifi
import csv
from bs4 import BeautifulSoup
import re
import pandas as pd
import datetime

#settings
http = urllib3.PoolManager(
        cert_reqs='CERT_REQUIRED',
        ca_certs=certifi.where())
today = datetime.datetime.today()
gamelog_defense = []
noGLteams = []
translator = pd.read_csv('./SRinput/valid_school_translation.csv')
HTTPnames = translator['HTTPname']

for school in HTTPnames:
    for year in range(2014, 2018):
        #scrape the data and write the .csv files
        url = "http://www.sports-reference.com/cfb/schools/"+school+"/"+str(year)+"/gamelog/"
        response = http.request('GET', url)
        soup = BeautifulSoup(response.data, features="html.parser")
        cnt = 0
        try:
            defense = soup.find(id="all_defense")
            for item in defense.children:
                if isinstance(item, bs4.element.Comment):
                    html = item
            Dsoup = BeautifulSoup(html, features="html.parser")
        except:
            html = ''
            Dsoup = BeautifulSoup(html, features="html.parser")
        
        for row in Dsoup.findAll('tr'):
            try:
                col1=row.findAll('th')
                Game=col1[0].string
                col=row.findAll('td')
                Date = col[0].get_text()
                Loc = col[1].get_text()
                Team = translator[translator['HTTPname'] == school]['School'].values[0]
                Opp = col[2].get_text()
                Result = col[3].get_text()
                Pass_cmp = col[4].get_text()
                Pass_att = col[5].get_text()
                Pass_pct = col[6].get_text()
                Pass_yds = col[7].get_text()
                Pass_TD = col[8].get_text()
                Rush_att = col[9].get_text()
                Rush_yds = col[10].get_text()
                Rush_avg = col[11].get_text()
                Rush_TD = col[12].get_text()
                TO_plays = col[13].get_text()
                TO_yds = col[14].get_text()
                TO_avg = col[15].get_text()
                FD_pass = col[16].get_text()
                FD_rush = col[17].get_text()
                FD_pen = col[18].get_text()
                FD_tot = col[19].get_text()
                Pen_num = col[20].get_text()
                Pen_yds = col[21].get_text()
                Turn_fum = col[22].get_text()
                Turn_int = col[23].get_text()
                Turn_tot = col[24].get_text()
                Season = year

                gamelog_defense.append([Season, Game, Date, Team, Loc, Opp, Result, Pass_cmp, Pass_att, Pass_pct, Pass_yds, Pass_TD,
                               Rush_att, Rush_yds, Rush_avg, Rush_TD, TO_plays, TO_yds, TO_avg, FD_pass,
                               FD_rush, FD_pen, FD_tot, Pen_num, Pen_yds, Turn_fum, Turn_int, Turn_tot])
                cnt += 1
            except:
                pass
        if cnt > 0:
            print("Finished writing defense " + str(year), school + " with " + str(cnt) + " records")
        else:
            noGLteams.append(school)
        
GL_defense_final=pd.DataFrame(gamelog_defense,columns=['Season', 'Game', 'Date', 'Team', 'Loc', 'Opp', 'Result', 'Pass_cmp',
                                              'Pass_att', 'Pass_pct', 'Pass_yds', 'Pass_TD',
                                              'Rush_att', 'Rush_yds', 'Rush_avg', 'Rush_TD', 'TO_plays',
                                              'TO_yds', 'TO_avg', 'FD_pass',
                                              'FD_rush', 'FD_pen', 'FD_tot', 'Pen_num', 'Pen_yds', 'Turn_fum',
                                              'Turn_int', 'Turn_tot'])
GL_defense_final.to_csv('./SRinput/GL_defense_2014_to_2017.csv')

# %% [markdown]
# ### Creates the in-season gamelog file

# %% [markdown]
# ### Work on Offense GL

# %%
# import packages
import urllib3
import certifi
import csv
from bs4 import BeautifulSoup
import re
import pandas as pd
import datetime

#settings
http = urllib3.PoolManager(
        cert_reqs='CERT_REQUIRED',
        ca_certs=certifi.where())
today = datetime.datetime.today()
gamelog_offense = []
translator = pd.read_csv('./SRinput/valid_school_translation.csv')
HTTPnames = translator['HTTPname']
year = 2018

for school in HTTPnames:
    #scrape the data and write the .csv files
    url = "http://www.sports-reference.com/cfb/schools/"+school+"/"+str(year)+"/gamelog/"
    response = http.request('GET', url)
    soup = BeautifulSoup(response.data, features="html.parser")
    cnt = 0
    #print(soup)

    for row in soup.findAll('tr'):
        try:
            col1=row.findAll('th')
            Game=col1[0].string
            col=row.findAll('td')
            Date = col[0].get_text()
            Loc = col[1].get_text()
            Team = translator[translator['HTTPname'] == school]['School'].values[0]
            Opp = col[2].get_text()
            Result = col[3].get_text()
            Pass_cmp = col[4].get_text()
            Pass_att = col[5].get_text()
            Pass_pct = col[6].get_text()
            Pass_yds = col[7].get_text()
            Pass_TD = col[8].get_text()
            Rush_att = col[9].get_text()
            Rush_yds = col[10].get_text()
            Rush_avg = col[11].get_text()
            Rush_TD = col[12].get_text()
            TO_plays = col[13].get_text()
            TO_yds = col[14].get_text()
            TO_avg = col[15].get_text()
            FD_pass = col[16].get_text()
            FD_rush = col[17].get_text()
            FD_pen = col[18].get_text()
            FD_tot = col[19].get_text()
            Pen_num = col[20].get_text()
            Pen_yds = col[21].get_text()
            Turn_fum = col[22].get_text()
            Turn_int = col[23].get_text()
            Turn_tot = col[24].get_text()
            Season = year

            gamelog_offense.append([Season, Game, Date, Team, Loc, Opp, Result, Pass_cmp, Pass_att, Pass_pct, Pass_yds, Pass_TD,
                           Rush_att, Rush_yds, Rush_avg, Rush_TD, TO_plays, TO_yds, TO_avg, FD_pass,
                           FD_rush, FD_pen, FD_tot, Pen_num, Pen_yds, Turn_fum, Turn_int, Turn_tot])
            cnt += 1
        except:
            pass
    print("Finished writing " + str(year), school + " with " + str(cnt) + " records")
        
GL_offense_season=pd.DataFrame(gamelog_offense,columns=['Season', 'Game', 'Date', 'Team', 'Loc', 'Opp', 'Result', 'Pass_cmp',
                                              'Pass_att', 'Pass_pct', 'Pass_yds', 'Pass_TD',
                                              'Rush_att', 'Rush_yds', 'Rush_avg', 'Rush_TD', 'TO_plays',
                                              'TO_yds', 'TO_avg', 'FD_pass',
                                              'FD_rush', 'FD_pen', 'FD_tot', 'Pen_num', 'Pen_yds', 'Turn_fum',
                                              'Turn_int', 'Turn_tot'])
GL_offense_season.to_csv('./SRinput/GL_offense_' + str(year) + '.csv')

# %%
#Prepare current season gamelogs for concat
GL_offense_season.set_index('Season', inplace=True)
GL_offense_season

# %%
#Read the history from disk and prepare for concat
GL_offense_history = pd.read_csv('./SRinput/GL_offense_2014_to_2017.csv')
GL_offense_history = GL_offense_history.drop('Unnamed: 0', axis=1)
GL_offense_history.set_index('Season', inplace=True)


#Combine history with current season
GL_offense_mstr = pd.concat([GL_offense_history, GL_offense_season])
#Drop the summary rows
GL_offense_mstr = GL_offense_mstr.dropna(subset=['Game'])

# %%
GL_offense_mstr

# %%
from jobs import SRjobs

GL_offense_mstr['Loc'] = GL_offense_mstr.apply(lambda x: SRjobs.winner_home(x['Loc']), axis=1)

# %%
GL_offense_mstr=GL_offense_mstr.rename(columns = {'Loc':'Game_home'})

# %%
GL_offense_mstr.to_csv('./SRinput/current/GL_offense.csv')

# %% [markdown]
# ### Work on Defense GL

# %%
# import packages
import urllib3
import certifi
import csv
from bs4 import BeautifulSoup
import re
import pandas as pd
import datetime

#settings
http = urllib3.PoolManager(
        cert_reqs='CERT_REQUIRED',
        ca_certs=certifi.where())
today = datetime.datetime.today()
gamelog_defense = []
translator = pd.read_csv('./SRinput/valid_school_translation.csv')
HTTPnames = translator['HTTPname']
year = 2018

for school in HTTPnames:
    #scrape the data and write the .csv files
    url = "http://www.sports-reference.com/cfb/schools/"+school+"/"+str(year)+"/gamelog/"
    response = http.request('GET', url)
    soup = BeautifulSoup(response.data, features="html.parser")
    cnt = 0
    # the defense table in gamelogs is one big ass comment, so it needs to be found and souped
    try:
        defense = soup.find(id="all_defense")
        for item in defense.children:
            if isinstance(item, bs4.element.Comment):
                html = item
        Dsoup = BeautifulSoup(html, features="html.parser")
    except:
        html = ''
        Dsoup = BeautifulSoup(html, features="html.parser")

    for row in Dsoup.findAll('tr'):
        try:
            col1=row.findAll('th')
            Game=col1[0].string
            col=row.findAll('td')
            Date = col[0].get_text()
            Loc = col[1].get_text()
            Team = translator[translator['HTTPname'] == school]['School'].values[0]
            Opp = col[2].get_text()
            Result = col[3].get_text()
            Pass_cmp = col[4].get_text()
            Pass_att = col[5].get_text()
            Pass_pct = col[6].get_text()
            Pass_yds = col[7].get_text()
            Pass_TD = col[8].get_text()
            Rush_att = col[9].get_text()
            Rush_yds = col[10].get_text()
            Rush_avg = col[11].get_text()
            Rush_TD = col[12].get_text()
            TO_plays = col[13].get_text()
            TO_yds = col[14].get_text()
            TO_avg = col[15].get_text()
            FD_pass = col[16].get_text()
            FD_rush = col[17].get_text()
            FD_pen = col[18].get_text()
            FD_tot = col[19].get_text()
            Pen_num = col[20].get_text()
            Pen_yds = col[21].get_text()
            Turn_fum = col[22].get_text()
            Turn_int = col[23].get_text()
            Turn_tot = col[24].get_text()
            Season = year

            gamelog_defense.append([Season, Game, Date, Team, Loc, Opp, Result, Pass_cmp, Pass_att, Pass_pct, Pass_yds, Pass_TD,
                           Rush_att, Rush_yds, Rush_avg, Rush_TD, TO_plays, TO_yds, TO_avg, FD_pass,
                           FD_rush, FD_pen, FD_tot, Pen_num, Pen_yds, Turn_fum, Turn_int, Turn_tot])
            cnt += 1
        except:
            pass
    print("Finished writing defense" + str(year), school + " with " + str(cnt) + " records")
        
GL_defense_season=pd.DataFrame(gamelog_defense,columns=['Season', 'Game', 'Date', 'Team', 'Loc', 'Opp', 'Result', 'Pass_cmp',
                                              'Pass_att', 'Pass_pct', 'Pass_yds', 'Pass_TD',
                                              'Rush_att', 'Rush_yds', 'Rush_avg', 'Rush_TD', 'TO_plays',
                                              'TO_yds', 'TO_avg', 'FD_pass',
                                              'FD_rush', 'FD_pen', 'FD_tot', 'Pen_num', 'Pen_yds', 'Turn_fum',
                                              'Turn_int', 'Turn_tot'])
GL_defense_season.to_csv('./SRinput/GL_defense_' + str(year) + '.csv')

# %%
#Prepare current season gamelogs for concat
GL_defense_season.set_index('Season', inplace=True)
GL_defense_season

# %%
#Read the history from disk and prepare for concat
GL_defense_history = pd.read_csv('./SRinput/GL_defense_2014_to_2017.csv')
GL_defense_history = GL_defense_history.drop('Unnamed: 0', axis=1)
GL_defense_history.set_index('Season', inplace=True)


#Combine history with current season
GL_defense_mstr = pd.concat([GL_defense_history, GL_defense_season])
#Drop the summary rows
GL_defense_mstr = GL_defense_mstr.dropna(subset=['Game'])

# %%
GL_defense_mstr

# %%
from jobs import SRjobs

GL_defense_mstr['Loc'] = GL_defense_mstr.apply(lambda x: SRjobs.winner_home(x['Loc']), axis=1)

# %%
GL_defense_mstr=GL_defense_mstr.rename(columns = {'Loc':'Game_home'})

# %%
GL_defense_mstr.to_csv('./SRinput/current/GL_defense.csv')

# %%
GL_defense_mstr[GL_defense_mstr['Team'] == 'Florida']
# Out:
#       Season  Game        Date     Team  Game_home                  Opp  \
# 1386    2014   1.0  2014-09-06  Florida          1     Eastern Michigan
# 1387    2014   2.0  2014-09-13  Florida          1             Kentucky
# 1388    2014   3.0  2014-09-20  Florida          0              Alabama
# 1389    2014   4.0  2014-10-04  Florida          0            Tennessee
# 1390    2014   5.0  2014-10-11  Florida          1      Louisiana State
# 1391    2014   6.0  2014-10-18  Florida          1             Missouri
# 1392    2014   7.0  2014-11-01  Florida          0              Georgia
# 1393    2014   8.0  2014-11-08  Florida          0           Vanderbilt
# 1394    2014   9.0  2014-11-15  Florida          1       South Carolina
# 1395    2014  10.0  2014-11-22  Florida          1     Eastern Kentucky
# 1396    2014  11.0  2014-11-29  Florida          0        Florida State
# 1397    2014  12.0  2015-01-03  Florida          0       East Carolina*
# 1398    2015   1.0  2015-09-05  Florida          1     New Mexico State
# 1399    2015   2.0  2015-09-12  Florida          1        East Carolina
# 1400    2015   3.0  2015-09-19  Florida          0             Kentucky
# 1401    2015   4.0  2015-09-26  Florida          1            Tennessee
# 1402    2015   5.0  2015-10-03  Florida          1          Mississippi
# 1403    2015   6.0  2015-10-10  Florida          0             Missouri
# 1404    2015   7.0  2015-10-17  Florida          0      Louisiana State
# 1405    2015   8.0  2015-10-31  Florida          0              Georgia
# 1406    2015   9.0  2015-11-07  Florida          1           Vanderbilt
# 1407    2015  10.0  2015-11-14  Florida          0       South Carolina
# 1408    2015  11.0  2015-11-21  Florida          1     Florida Atlantic
# 1409    2015  12.0  2015-11-28  Florida          1        Florida State
# 1410    2015  13.0  2015-12-05  Florida          0              Alabama
# 1411    2015  14.0  2016-01-01  Florida          0            Michigan*
# 1412    2016   1.0  2016-09-03  Florida          1        Massachusetts
# 1413    2016   2.0  2016-09-10  Florida          1             Kentucky
# 1414    2016   3.0  2016-09-17  Florida          1          North Texas
# 1415    2016   4.0  2016-09-24  Florida          0            Tennessee
# ...      ...   ...         ...      ...        ...                  ...
# 1418    2016   7.0  2016-10-29  Florida          0              Georgia
# 1419    2016   8.0  2016-11-05  Florida          0             Arkansas
# 1420    2016   9.0  2016-11-12  Florida          1       South Carolina
# 1421    2016  10.0  2016-11-19  Florida          0      Louisiana State
# 16       6.3        4        9       1      14        7       35         0
# 17       4.8        8        9       2      19        1       10         2
# 18       6.8       14        7       1      22        9       87         0
# 19       5.6        9        3       0      12        5       39         0
# 20       3.8        7        0       0       7        9       86         2
# 21       3.3        2        6       1       9        4       27         0
# 22       6.3       14        5       0      19        2       21         0
# 23       4.7       11        5       4      20        4       45         0
# 24       7.9        4       13       0      17        3       25         0
# 25       7.3        6       11       0      17        5       39         1
# 26       8.3       16        9       2      27        5       29         1
# 27       5.6        9        4       3      16        8       59         0
# 28       4.1        6        0       0       6        5       25         0
# 29       5.2       15        4       3      22        7       46         1
# ...      ...      ...      ...     ...     ...      ...      ...       ...
# 8037     7.7       13       10       2      25        7       56         0
# 8038     7.0       10       13       1      24        8       75         0
# 8039     6.7       14        7       1      22        6       49         0
# 8040     4.1        8        8       0      16        5       45         1
# 8041     8.5       14       16       2      32        2       20         1
# 8042     4.8        8        6       1      15        6       65         1
# 8043     3.9        8        5       1      14        1       10         1
# 8044     6.1        5        8       1      14        4       36         0
# 8045     7.5       11        5       3      19        1        5         2
# 8046     7.6       17        7       2      26       10      100         1
# 8047     6.4        5       14       2      21        1       15         0
# 8048     5.3        2        9       2      13        3       25         2
# 8049     4.4        8        9       2      19        3       20         0
# 8050     5.1       10        2       1      13        4       50         0
# 8051     4.8        8       13       2      23        3       22         2
# 8052     5.8       16        6       6      28        5       48         1
# 8053     5.2        7       11       1      19        2       20         0
# 8054     4.5       13        5       1      19        5       40         0
# 8055     2.8        5        2       0       7       12       57         0
# 8056     5.1       15        5       4      24       10       75         1
# 8057     6.6       23       10       0      33        8       79         1
# 8058     4.6        4        8       2      14        3       16         1
# 8059     5.7       14       11       4      29        9       71         0
# 8060     4.6        6       13       0      19        2       25         1
# 8061     6.0       11        6       0      17        5       45         0
# 8062     3.2        1        8       2      11        6       52         0
# 8063     4.8       19        3       1      23        3       26         1
# 8064     4.4        9        5       1      15        6       45         0
# 8065     5.6        3       22       0      25        5       66         0
# 8066     1.6        1        3       2       6        2       20         0
#
#       Turn_int  Turn_tot
# 0            0         0
# 1            0         0
# 2            1         1
# 3            5         7
# 4            1         2
# 5            0         1
# 6            0         2
# 7            0         1
# 8            0         0
# 9            1         1
# 10           1         1
# 11           1         1
# 12           0         1
# 13           1         2
# 14           2         2
# 15           0         0
# 16           0         0
# 17           2         4
# 18           1         1
# 19           1         1
# 20           2         4
# 21           0         0
# 22           1         1
# 23           0         0
# 24           1         1
# 25           0         1
# 26           0         1
# 27           0         0
# 28           0         0
# 29           1         2
# ...        ...       ...
# 8037         0         0
# 8038         0         0
# 8039         2         2
# 8040         2         3
# 8041         0         1
# 8042         1         2
# 8043         2         3
# 8044         0         0
# 8045         1         3
# 8046         0         1
# 8047         0         0
# 8048         3         5
# 8049         3         3
# 8050         0         0
# 8051         0         2
# 8052         0         1
# 8053         0         0
# 8054         1         1
# 8055         0         0
# 8056         1         2
# 8057         0         1
# 8058         2         3
# 8059         0         0
# 8060         1         2
# 8061         0         0
# 8062         1         1
# 8063         2         3
# 8064         0         0
# 8065         2         2
# 8066         1         1
#
# [8067 rows x 28 columns]
