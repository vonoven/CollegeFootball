# %%
# import packages
import urllib3
import csv
from bs4 import BeautifulSoup
import re
import pandas as pd
import datetime

#settings
http = urllib3.PoolManager()
conf_list = ['acc', 'american', 'big-12', 'big-ten', 'cusa', 'independent', 'mac', 'mwc', 'pac-12',
            'sec', 'sun-belt']
today = datetime.datetime.today()
conference = []

#scrape the data and write the .csv files
for conf in conf_list:
    url = "http://www.sports-reference.com/cfb/conferences/"+conf+"/schools.html"
    response = http.request('GET', url)
    soup = BeautifulSoup(response.data)
    cnt = 0
    for row in soup.findAll('tr'):
        try:
            col1=row.findAll('th')
            Rank=col1[0].string
            col=row.findAll('td')
            School = col[0].get_text()
            From = col[1].get_text()
            To = col[2].get_text()
            Yrs = col[3].get_text()
            Games = col[4].get_text()
            Wins = col[5].get_text()
            Losses = col[6].get_text()
            Ties = col[7].get_text()
            Pct = col[8].get_text()
            C_games = col[9].get_text()
            C_wins = col[10].get_text()
            C_losses = col[11].get_text()
            C_ties = col[12].get_text()
            C_pct = col[13].get_text()
            conference.append([conf, School, From, To, Yrs, Games, Wins, Losses, Ties, Pct, 
                      C_games, C_wins, C_losses, C_ties, C_pct])
            cnt += 1
        except:
            pass
    print("Finished writing " + conf + " conference with " + str(cnt) + " schools")
# Out:
# /anaconda3/envs/TensorFlow/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Finished writing acc conference with 16 schools
# /anaconda3/envs/TensorFlow/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Finished writing american conference with 14 schools
# /anaconda3/envs/TensorFlow/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Finished writing big-12 conference with 14 schools
# /anaconda3/envs/TensorFlow/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Finished writing big-ten conference with 15 schools
# /anaconda3/envs/TensorFlow/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Finished writing cusa conference with 26 schools
# /anaconda3/envs/TensorFlow/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Finished writing independent conference with 252 schools
# /anaconda3/envs/TensorFlow/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Finished writing mac conference with 16 schools
# /anaconda3/envs/TensorFlow/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Finished writing mwc conference with 15 schools
# /anaconda3/envs/TensorFlow/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Finished writing pac-12 conference with 14 schools
# /anaconda3/envs/TensorFlow/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Finished writing sec conference with 17 schools
# /anaconda3/envs/TensorFlow/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Finished writing sun-belt conference with 18 schools

# %%
df=pd.DataFrame(conference,columns=['Conf', 'School', 'From', 'To', 'Yrs', 'Games', 'Wins', 'Losses', 'Ties', 'Pct', 
                      'C_games', 'C_wins', 'C_losses', 'C_ties', 'C_pct'])

# %%
df
# Out:
#          Conf                  School  From    To Yrs Games Wins Losses Ties  \
# 0         acc           Florida State  1992  2018  27   336  263     82    1
# 1         acc           Virginia Tech  2004  2018  15   197  136     61    0
# 2         acc              Miami (FL)  2004  2018  15   188  114     74    0
# 3         acc                 Clemson  1953  2018  66   761  486    266   13
# 4         acc              Louisville  2014  2018   5    63   36     27    0
# 5         acc            Georgia Tech  1983  2018  36   429  245    188    4
# 6         acc                    Pitt  2013  2018   6    75   41     34    0
# 7         acc          Boston College  2005  2018  14   178   98     80    0
# 8         acc          North Carolina  1953  2018  66   738  395    352    8
# 9         acc    North Carolina State  1953  2018  66   737  389    351   15
# 10        acc                Syracuse  2013  2018   6    72   30     42    0
# 11        acc                    Duke  1953  2018  66   730  297    421   16
# 12        acc                Virginia  1954  2018  65   723  322    407    6
# 413  sun-belt        Florida Atlantic  2004  2012   9   107   44     65    0
# 414  sun-belt             North Texas  2001  2012  12   142   51     94    0
# 415  sun-belt   Florida International  2004  2012   9   107   35     72    0
# 416  sun-belt              Utah State  2003  2004   2    23    6     17    0
#
#       Pct C_games C_wins C_losses C_ties C_pct
# 0    .762     217    168       48      0  .778
# 1    .690     120     83       36      0  .697
# 2    .606     119     66       53      0  .555
# 3    .644     453    302      145      6  .673
# 4    .571      40     21       19      0  .525
# 5    .565     274    151      121      2  .555
# 6    .547      47     27       20      0  .574
# 7    .551     111     52       59      0  .468
# 8    .528     466    237      224      5  .514
# 9    .525     456    223      225      8  .498
# 10   .417      47     16       31      0  .340
# 11   .416     451    161      282      8  .366
# 12   .442     436    175      257      4  .406
# 13   .376     465    140      320      5  .306
# 14   .510     410    211      195      4  .520
# 15   .470     114     56       54      4  .509
# 16   .697      47     32       15      0  .681
# 17   .676      47     34       13      0  .723
# 18   .588      31     20       11      0  .645
# 19   .627      47     29       18      0  .617
# 20   .553      47     29       18      0  .617
# 21   .568      47     25       22      0  .532
# 22   .575      47     27       20      0  .574
# 23   .373      39     12       27      0  .308
# 24   .361      39     13       26      0  .333
# 25   .339      39     11       28      0  .282
# 26   .347      47     17       30      0  .362
# 27   .250      47     11       36      0  .234
# 28   .923       8      7        1      0  .875
# 29   .462       8      3        5      0  .375
# ..    ...     ...    ...      ...    ...   ...
# 387  .627     561    321      225     15  .586
# 388  .631     590    317      253     19  .554
# 389  .580      55     26       29      0  .473
# 390  .581     570    264      291     15  .476
# 391  .526     215     90      123      2  .423
# 392  .534     217     94      121      1  .438
# 393  .502     572    201      358     13  .363
# 394  .458     567    172      383     12  .314
# 395  .387     574    137      419     18  .254
# 396  .464     195     69      113     13  .387
# 397  .646     195    116       70      9  .618
# 398  .225      36      0       36      0  .000
# 399  .738      39     33        6      0  .846
# 400  .550      40     26       14      0  .650
# 401  .560     114     76       38      0  .667
# 402  .514     131     84       47      0  .641
# 403  .465     132     74       58      0  .561
# 404  .360      54     19       35      0  .352
# 405  .369     132     62       70      0  .470
# 406  .348      15      4       11      0  .267
# 407  .264      46     13       33      0  .283
# 408  .324      47     12       35      0  .255
# 409  .365      58     26       32      0  .448
# 410  .284      58     20       38      0  .345
# 411  .393      39     17       22      0  .436
# 412  .472      88     50       38      0  .568
# 413  .404      67     30       37      0  .448
# 414  .352      88     42       46      0  .477
# 415  .327      65     24       41      0  .369
# 416  .261      13      5        8      0  .385
#
# [417 rows x 15 columns]

# %%
df.to_csv('./input/conference_master.csv')
